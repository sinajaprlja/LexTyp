# %% [markdown]
# ## Wictionary Data Inspection on one Example

# %%
import json
from typing import Any

# %%
def pprint(data: Any) -> None:
    """
    Using json to pretty print data.
    """
    print(json.dumps(data, indent=4, ensure_ascii=False))

# %% [markdown]
# Defining example data taken from full dataset.

# %%
data = {"pos": "verb", "head_templates": [{"name": "en-verb", "args": {}, "expansion": "pound (third-person singular simple present pounds, present participle pounding, simple past and past participle pounded)"}], "forms": [{"form": "pounds", "tags": ["present", "singular", "third-person"]}, {"form": "pounding", "tags": ["participle", "present"]}, {"form": "pounded", "tags": ["participle", "past"]}, {"form": "pounded", "tags": ["past"]}, {"form": "poun", "tags": ["alternative"]}, {"form": "pown", "tags": ["alternative"]}], "etymology_number": 3, "etymology_text": "From an alteration of earlier poun, pown, from Middle English pounen, from Old English pūnian (“to pound, beat, bray, bruise, crush”), from Proto-West Germanic *pūn- (“broken pieces, rubble”). Related to Saterland Frisian Pün (“debris, fragments”), West Frisian pún (“debris, rubble”), Dutch puin (“debris, fragments, rubbish”), Low German pun (“fragments”).", "etymology_templates": [{"name": "inh", "args": {"1": "en", "2": "enm", "3": "pounen"}, "expansion": "Middle English pounen"}, {"name": "inh", "args": {"1": "en", "2": "ang", "3": "pūnian", "4": "", "5": "to pound, beat, bray, bruise, crush"}, "expansion": "Old English pūnian (“to pound, beat, bray, bruise, crush”)"}, {"name": "der", "args": {"1": "en", "2": "gmw-pro", "3": "*pūn-", "t": "broken pieces, rubble"}, "expansion": "Proto-West Germanic *pūn- (“broken pieces, rubble”)"}, {"name": "cog", "args": {"1": "stq", "2": "Pün", "t": "debris, fragments"}, "expansion": "Saterland Frisian Pün (“debris, fragments”)"}, {"name": "cog", "args": {"1": "fy", "2": "pún", "t": "debris, rubble"}, "expansion": "West Frisian pún (“debris, rubble”)"}, {"name": "cog", "args": {"1": "nl", "2": "puin", "3": "", "4": "debris, fragments, rubbish"}, "expansion": "Dutch puin (“debris, fragments, rubbish”)"}, {"name": "cog", "args": {"1": "nds", "2": "pun", "3": "", "4": "fragments"}, "expansion": "Low German pun (“fragments”)"}], "word": "pound", "lang": "English", "lang_code": "en", "sounds": [{"ipa": "/paʊnd/"}, {"audio": "en-us-pound.ogg", "ogg_url": "https://upload.wikimedia.org/wikipedia/commons/5/58/En-us-pound.ogg", "mp3_url": "https://upload.wikimedia.org/wikipedia/commons/transcoded/5/58/En-us-pound.ogg/En-us-pound.ogg.mp3"}, {"rhymes": "-aʊnd"}], "synonyms": [{"english": "to strike a blow with the hand/fist", "word": "buffet", "_dis1": "0 0 0 0 0 0 0 0"}], "derived": [{"word": "enough sense to pound sand into a rathole", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "ground and pound", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound a beat", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound dirt", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound down", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pounding", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound out", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound salt", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound sand", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound sand into a rathole", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound the pavement", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound the table", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound town", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pound up", "_dis1": "0 0 0 0 0 0 0 0"}, {"word": "pulse-pounding", "_dis1": "0 0 0 0 0 0 0 0"}], "related": [{"word": "bang", "_dis1": "0 0 0 0 0 0 0 0"}], "senses": [{"examples": [{"text": "She had Lord James' collar in one big fist and she pounded the table with the other and talked a blue streak. Nobody could make out plain what she said, for she was mainly jabbering Swede lingo, but there was English enough, of a kind, to give us some idee.", "ref": "1913, Joseph C[rosby] Lincoln, chapter XII, in Mr. Pratt’s Patients, New York, N.Y., London: D[aniel] Appleton and Company, →OCLC:", "type": "quote"}, {"text": "[...] and on the Saturday heavy seas pounded the W.R. on its exposed coastal stretch between Dawlish and Teignmouth, loosening the ballast and forcing trains to proceed with extreme caution.", "ref": "1960 December, “Talking of Trains: The railways and the Devon floods”, in Trains Illustrated, page 709:", "type": "quote"}, {"text": "I pounded on a farmhouse / Lookin' for a place to stay / I was mighty, mighty tired / I had come a long, long way", "ref": "1964, Bob Dylan (lyrics and music), “Motorpsycho Nitemare”:", "type": "quote"}], "links": [["strike", "strike"], ["hard", "hard"], ["repeated", "repeated"]], "synonyms": [{"word": "hammer"}, {"word": "pelt"}, {"word": "hit"}], "raw_glosses": ["(transitive) To strike hard, usually repeatedly."], "glosses": ["To strike hard, usually repeatedly."], "tags": ["transitive"], "id": "en-pound-en-verb-L6h-rYLv", "categories": [], "translations": [{"lang": "Bulgarian", "code": "bg", "sense": "to strike hard repeatedly", "roman": "udrjam", "word": "удрям", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Bulgarian", "code": "bg", "sense": "to strike hard repeatedly", "roman": "blǎskam", "word": "блъскам", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Czech", "code": "cs", "sense": "to strike hard repeatedly", "word": "bušit", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Dutch", "code": "nl", "sense": "to strike hard repeatedly", "word": "beuken", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Ewe", "code": "ee", "sense": "to strike hard repeatedly", "word": "to", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Finnish", "code": "fi", "sense": "to strike hard repeatedly", "word": "takoa", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Finnish", "code": "fi", "sense": "to strike hard repeatedly", "word": "rusikoida", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "French", "code": "fr", "sense": "to strike hard repeatedly", "word": "pilonner", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Galician", "code": "gl", "sense": "to strike hard repeatedly", "word": "mazar", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Greek", "code": "el", "sense": "to strike hard repeatedly", "roman": "sfyrokopó", "word": "σφυροκοπώ", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Hungarian", "code": "hu", "sense": "to strike hard repeatedly", "word": "dobogtat", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Icelandic", "code": "is", "sense": "to strike hard repeatedly", "word": "banga", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Irish", "code": "ga", "sense": "to strike hard repeatedly", "word": "tuargain", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Italian", "code": "it", "sense": "to strike hard repeatedly", "word": "battere", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Italian", "code": "it", "sense": "to strike hard repeatedly", "word": "martellare", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Italian", "code": "it", "sense": "to strike hard repeatedly", "word": "colpire", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Italian", "code": "it", "sense": "to strike hard repeatedly", "word": "pestare", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Italian", "code": "it", "sense": "to strike hard repeatedly", "word": "flagellare", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Latin", "code": "la", "sense": "to strike hard repeatedly", "word": "pīnsō", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Latin", "code": "la", "sense": "to strike hard repeatedly", "word": "cūdō", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Latin", "code": "la", "sense": "to strike hard repeatedly", "word": "tundō", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Lithuanian", "code": "lt", "sense": "to strike hard repeatedly", "word": "daužyti", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Maori", "code": "mi", "sense": "to strike hard repeatedly", "word": "pātukituki", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Maori", "code": "mi", "sense": "to strike hard repeatedly", "word": "tuki", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Middle English", "code": "enm", "sense": "to strike hard repeatedly", "word": "pounen", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Old Norse", "code": "non", "sense": "to strike hard repeatedly", "word": "banga", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Ottoman Turkish", "code": "ota", "sense": "to strike hard repeatedly", "roman": "çalmak", "word": "چالمق", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Polish", "code": "pl", "sense": "to strike hard repeatedly", "tags": ["imperfective"], "word": "walić", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Polish", "code": "pl", "sense": "to strike hard repeatedly", "tags": ["perfective"], "word": "walnąć", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Polish", "code": "pl", "sense": "to strike hard repeatedly", "tags": ["perfective"], "word": "bachnąć", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Portuguese", "code": "pt", "sense": "to strike hard repeatedly", "word": "bater", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Quechua", "code": "qu", "sense": "to strike hard repeatedly", "word": "takay", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Romanian", "code": "ro", "sense": "to strike hard repeatedly", "word": "pisa", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Romanian", "code": "ro", "sense": "to strike hard repeatedly", "word": "bate", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Russian", "code": "ru", "sense": "to strike hard repeatedly", "roman": "kolotítʹ", "tags": ["imperfective"], "word": "колоти́ть", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Scots", "code": "sco", "sense": "to strike hard repeatedly", "word": "pran", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Scottish Gaelic", "code": "gd", "sense": "to strike hard repeatedly", "word": "buail", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Slovak", "code": "sk", "sense": "to strike hard repeatedly", "word": "biť", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Slovak", "code": "sk", "sense": "to strike hard repeatedly", "word": "tĺcť", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Spanish", "code": "es", "sense": "to strike hard repeatedly", "word": "pilar", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Swedish", "code": "sv", "sense": "to strike hard repeatedly", "word": "banka", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Telugu", "code": "te", "sense": "to strike hard repeatedly", "roman": "dañcu", "word": "దంచు", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Tetum", "code": "tet", "sense": "to strike hard repeatedly", "word": "fai", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Tetum", "code": "tet", "sense": "to strike hard repeatedly", "word": "tuku", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Thai", "code": "th", "sense": "to strike hard repeatedly", "roman": "túp", "word": "ทุบ", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "Thai", "code": "th", "sense": "to strike hard repeatedly", "roman": "dtii", "word": "ตี", "_dis1": "99 0 0 0 0 1 0 0"}, {"lang": "ǃXóõ", "code": "nmn", "sense": "to strike hard repeatedly", "word": "!qhāã", "_dis1": "99 0 0 0 0 1 0 0"}]}, {"examples": [{"text": "Pound an onion, warm a spoonful of ghee and throw in the onion, brown it slightly, add your curry stuff, brown this till it smells pleasantly, […]", "ref": "1887, Indian Cookery \"Local\" for Young Housekeepers: Second Edition, page 67:", "type": "quote"}, {"text": "It was the hour before the first crowing of the cocks, and along with Nyo Boto and Grandma Yaisa's clattering, the first sound the child heard was the muted, rhythmic bombpabombpabomp of wooden pestles as the other women of the village pounded couscous grain in their mortars, preparing the traditional breakfast of porridge that was cooked in earthen pots over a fire built among three rocks.", "ref": "1976, Alex Haley, chapter 1, in Roots: The Saga of an American Family:", "type": "quote"}], "senseid": ["en:to crush"], "links": [["crush", "crush"], ["pulverize", "pulverize"]], "synonyms": [{"word": "pulverate"}, {"word": "triturate"}], "raw_glosses": ["(transitive) To crush to pieces; to pulverize."], "glosses": ["To crush to pieces; to pulverize."], "tags": ["transitive"], "id": "en-pound-en-verb-en:to_crush", "categories": [], "translations": [{"lang": "Aromanian", "code": "rup", "sense": "crush to pieces", "word": "chisedz", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Assamese", "code": "as", "sense": "crush to pieces", "roman": "khundo", "word": "খুন্দ", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Belarusian", "code": "be", "sense": "crush to pieces", "roman": "taŭčý", "tags": ["imperfective"], "word": "таўчы́", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Bulgarian", "code": "bg", "sense": "crush to pieces", "roman": "strivam", "word": "стривам", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Bulgarian", "code": "bg", "sense": "crush to pieces", "roman": "sčukvam", "word": "счуквам", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Cherokee", "code": "chr", "sense": "crush to pieces", "roman": "asdoa", "word": "ᎠᏍᏙᎠ", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Esperanto", "code": "eo", "sense": "crush to pieces", "word": "pisti", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Ewe", "code": "ee", "sense": "crush to pieces", "word": "to", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Finnish", "code": "fi", "sense": "crush to pieces", "word": "murskata", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Galician", "code": "gl", "sense": "crush to pieces", "word": "triturar", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Galician", "code": "gl", "sense": "crush to pieces", "word": "pulverizar", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "German", "code": "de", "sense": "crush to pieces", "word": "zerstampfen", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Greek", "code": "el", "sense": "crush to pieces", "roman": "dialýo", "word": "διαλύω", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Higaonon", "code": "mba", "sense": "crush to pieces", "word": "asud", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Icelandic", "code": "is", "sense": "crush to pieces", "word": "banga", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Italian", "code": "it", "sense": "crush to pieces", "word": "frantumare", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Italian", "code": "it", "sense": "crush to pieces", "word": "tritare", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Italian", "code": "it", "sense": "crush to pieces", "word": "triturare", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Italian", "code": "it", "sense": "crush to pieces", "word": "polverizzare", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Korean", "code": "ko", "sense": "crush to pieces", "alt": "(bang'a)jjita", "word": "(방아)찧다", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Korean", "code": "ko", "sense": "crush to pieces", "roman": "ppata", "word": "빻다", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Middle English", "code": "enm", "sense": "crush to pieces", "word": "pounen", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Middle English", "code": "enm", "sense": "crush to pieces", "word": "brayen", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Old Norse", "code": "non", "sense": "crush to pieces", "word": "banga", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Portuguese", "code": "pt", "sense": "crush to pieces", "word": "triturar", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Portuguese", "code": "pt", "sense": "crush to pieces", "word": "pulverizar", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Romanian", "code": "ro", "sense": "crush to pieces", "word": "pisa", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Russian", "code": "ru", "sense": "crush to pieces", "roman": "tolóčʹ", "tags": ["imperfective"], "word": "толо́чь", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Russian", "code": "ru", "sense": "crush to pieces", "roman": "razdrobljátʹ", "tags": ["imperfective"], "word": "раздробля́ть", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Russian", "code": "ru", "sense": "crush to pieces", "roman": "drobítʹ", "tags": ["imperfective"], "word": "дроби́ть", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Russian", "code": "ru", "sense": "crush to pieces", "roman": "molótʹ", "tags": ["imperfective"], "word": "моло́ть", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Russian", "code": "ru", "sense": "crush to pieces", "roman": "krošítʹ", "tags": ["imperfective"], "word": "кроши́ть", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Scots", "code": "sco", "sense": "crush to pieces", "word": "champ", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Scots", "code": "sco", "sense": "crush to pieces", "word": "pran", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Slovak", "code": "sk", "sense": "crush to pieces", "word": "drviť", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Slovak", "code": "sk", "sense": "crush to pieces", "word": "rozdrviť", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Spanish", "code": "es", "sense": "crush to pieces", "word": "pulverizar", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Telugu", "code": "te", "sense": "crush to pieces", "roman": "dañcu", "word": "దంచు", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Thai", "code": "th", "sense": "crush to pieces", "roman": "dtam", "word": "ตำ", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Thai", "code": "th", "sense": "crush to pieces", "roman": "bòt", "word": "บด", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Turkish", "code": "tr", "sense": "crush to pieces", "word": "parçalara ayırmak", "_dis1": "0 96 1 0 1 1 1 1"}, {"lang": "Ukrainian", "code": "uk", "sense": "crush to pieces", "roman": "tovktý", "tags": ["imperfective"], "word": "товкти́", "_dis1": "0 96 1 0 1 1 1 1"}]}, {"examples": [{"text": "You really pounded that beer!", "type": "example"}, {"text": "The sounds of a house-party rolled down the street / So we pounded our Pilsner and leapt to our feet", "ref": "2007, “Fire Marshall Willy”, performed by The Dreadnoughts:", "type": "quote"}], "synonyms": [{"word": "bolt"}, {"word": "down"}, {"word": "chug"}, {"word": "eat"}, {"word": "drink"}], "raw_glosses": ["(transitive, slang) To eat or drink very quickly."], "glosses": ["To eat or drink very quickly."], "tags": ["slang", "transitive"], "id": "en-pound-en-verb-AckZL1kj", "categories": [], "translations": [{"lang": "Bulgarian", "code": "bg", "sense": "slang: eat or drink quickly", "roman": "tǎpča se", "word": "тъпча се", "_dis1": "1 2 82 4 2 5 3 2"}, {"lang": "Finnish", "code": "fi", "sense": "slang: eat or drink quickly", "word": "imaista", "_dis1": "1 2 82 4 2 5 3 2"}, {"lang": "Italian", "code": "it", "sense": "slang: eat or drink quickly", "word": "ingurgitare", "_dis1": "1 2 82 4 2 5 3 2"}, {"lang": "Italian", "code": "it", "sense": "slang: eat or drink quickly", "word": "trangugiare", "_dis1": "1 2 82 4 2 5 3 2"}, {"lang": "Italian", "code": "it", "sense": "slang: eat or drink quickly", "word": "affogarsi", "_dis1": "1 2 82 4 2 5 3 2"}, {"lang": "Portuguese", "code": "pt", "sense": "slang: eat or drink quickly", "word": "devorar", "_dis1": "1 2 82 4 2 5 3 2"}, {"lang": "Russian", "code": "ru", "sense": "slang: eat or drink quickly", "tags": ["imperfective", "slang"], "english": "to eat", "roman": "lópatʹ", "word": "ло́пать", "_dis1": "1 2 82 4 2 5 3 2"}]}, {"examples": [{"text": "The pitcher has been pounding the outside corner all night.", "type": "example"}], "topics": ["ball-games", "baseball", "games", "hobbies", "lifestyle", "sports"], "links": [["baseball", "baseball"], ["pitch", "pitch"]], "raw_glosses": ["(transitive, baseball, slang) To pitch consistently to a certain location."], "glosses": ["To pitch consistently to a certain location."], "tags": ["slang", "transitive"], "id": "en-pound-en-verb-Uu1IJJuQ", "categories": [{"name": "Baseball", "kind": "topical", "parents": ["Ball games", "Sports", "Human activity", "Human behaviour", "Human", "All topics", "Fundamental"], "source": "w", "orig": "en:Baseball", "langcode": "en"}], "translations": [{"lang": "Finnish", "code": "fi", "sense": "baseball: to pitch consistently to a certain location", "word": "pommittaa", "_dis1": "1 1 2 91 1 1 2 1"}]}, {"examples": [{"text": "As I tiptoed past the sleeping dog, my heart was pounding but I remained silent.", "type": "example"}, {"text": "My head was pounding.", "type": "example"}, {"text": "It was now about three o’clock in the morning and Francis Macomber, who had been asleep a little while after he had stopped thinking about the lion, wakened and then slept again, woke suddenly, frightened in a dream of the bloody-headed lion standing over him, and listening while his heart pounded, he realized that his wife was not in the other cot in the tent.", "ref": "1936, Ernest Hemingway, The Short, Happy Life of Francis Macomber:", "type": "quote"}], "links": [["beat", "beat"], ["throb", "throb"]], "raw_glosses": ["(intransitive, of a body part, generally heart, blood, or head) To beat strongly or throb."], "qualifier": "generally heart; blood; or head; generally heart; blood; or head", "glosses": ["To beat strongly or throb."], "tags": ["intransitive"], "raw_tags": ["of a body part"], "id": "en-pound-en-verb-EVAp2T6q", "categories": [], "translations": [{"lang": "Finnish", "code": "fi", "sense": "to beat strongly or throb", "word": "hakata", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Finnish", "code": "fi", "sense": "to beat strongly or throb", "word": "jyskyttää", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "German", "code": "de", "sense": "to beat strongly or throb", "word": "klopfen", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Hungarian", "code": "hu", "sense": "to beat strongly or throb", "word": "dobogtat", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Italian", "code": "it", "sense": "to beat strongly or throb", "word": "battere", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Italian", "code": "it", "sense": "to beat strongly or throb", "word": "picchiare", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Polish", "code": "pl", "sense": "to beat strongly or throb", "tags": ["imperfective"], "note": "of heart", "word": "walić", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Slovak", "code": "sk", "sense": "to beat strongly or throb", "word": "biť", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Slovak", "code": "sk", "sense": "to beat strongly or throb", "word": "búšiť", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Slovak", "code": "sk", "sense": "to beat strongly or throb", "word": "pulzovať", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Swedish", "code": "sv", "sense": "to beat strongly or throb", "word": "slå", "_dis1": "1 1 3 1 90 3 1 1"}, {"lang": "Swedish", "code": "sv", "sense": "to beat strongly or throb", "word": "bulta", "_dis1": "1 1 3 1 90 3 1 1"}]}, {"examples": [{"text": "I was pounding her all night!", "type": "example"}, {"text": "She acting, so I'm attacking, try break the mattress / Sexy, so I suggested to switch to sideways / Pounded for 'bout a hour she said she tired", "ref": "2008, Gucci Mane (lyrics and music), “Bachelor Pad”, in The Movie:", "type": "quote"}], "links": [["penetrate", "penetrate"], ["sexual", "sexual"], ["vigour", "vigour"]], "synonyms": [{"word": "drill"}, {"word": "get up in"}, {"word": "nail"}, {"word": "poke"}, {"word": "copulate with"}], "raw_glosses": ["(transitive, vulgar, slang) To penetrate sexually, with vigour."], "glosses": ["To penetrate sexually, with vigour."], "tags": ["slang", "transitive", "vulgar"], "id": "en-pound-en-verb-~SWlKcga", "categories": [], "translations": [{"lang": "Bulgarian", "code": "bg", "sense": "slang: to penetrate sexually, with vigour", "roman": "čukam", "word": "чукам", "_dis1": "1 1 3 3 1 89 2 2"}, {"lang": "Finnish", "code": "fi", "sense": "slang: to penetrate sexually, with vigour", "word": "ryskyttää", "_dis1": "1 1 3 3 1 89 2 2"}, {"lang": "French", "code": "fr", "sense": "slang: to penetrate sexually, with vigour", "word": "pilonner", "_dis1": "1 1 3 3 1 89 2 2"}, {"lang": "Polish", "code": "pl", "sense": "slang: to penetrate sexually, with vigour", "tags": ["imperfective"], "word": "walić", "_dis1": "1 1 3 3 1 89 2 2"}, {"lang": "Portuguese", "code": "pt", "sense": "slang: to penetrate sexually, with vigour", "word": "socar", "_dis1": "1 1 3 3 1 89 2 2"}]}, {"examples": [{"text": "We pounded along, stopped, landed soldiers; went on, landed custom–house clerks to levy toll in what looked like a God–forsaken wilderness, with a tin shed and a flag–pole lost in it; landed more soldiers—to take care of the custom–house clerks, presumably.", "ref": "1899 February, Joseph Conrad, “The Heart of Darkness”, in Blackwood’s Edinburgh Magazine, volume CLXV, number M, New York, N.Y.: The Leonard Scott Publishing Company, […], →OCLC, part I:", "type": "quote"}], "glosses": ["To advance heavily with measured steps."], "id": "en-pound-en-verb-lQogR4uO", "categories": [], "translations": [{"lang": "Finnish", "code": "fi", "sense": "to advance heavily with measured steps", "word": "marssia", "_dis1": "0 1 2 1 1 1 92 1"}]}, {"examples": [{"text": "The engine pounds.", "type": "example"}], "topics": ["engineering", "natural-sciences", "physical-sciences"], "links": [["engineering", "engineering#Noun"], ["jarring", "jarring"], ["noise", "noise"]], "raw_glosses": ["(engineering) To make a jarring noise, as when running."], "glosses": ["To make a jarring noise, as when running."], "id": "en-pound-en-verb-ilmled9H", "categories": [{"name": "Engineering", "kind": "topical", "parents": ["Applied sciences", "Technology", "Sciences", "All topics", "Fundamental"], "source": "w", "orig": "en:Engineering", "langcode": "en"}], "translations": [{"lang": "Finnish", "code": "fi", "sense": "to make a jarring noise", "word": "jyskyttää", "_dis1": "0 3 2 1 2 6 2 83"}, {"lang": "Haryanvi", "code": "bgc", "sense": "to make a jarring noise", "roman": "khuṛkā", "word": "खुड़का", "_dis1": "0 3 2 1 2 6 2 83"}]}]}

# %% [markdown]
# Pretty-Print data for a better overview of its structure.

# %%
pprint(data)
# Out:
# {
#     "pos": "verb",
#     "head_templates": [
#         {
#             "name": "en-verb",
#             "args": {},
#             "expansion": "pound (third-person singular simple present pounds, present participle pounding, simple past and past participle pounded)"
#         }
#     ],
#     "forms": [
#         {
#             "form": "pounds",
#             "tags": [
#                 "present",
#                 "singular",
#                 "third-person"
#             ]
#         },
#         {
#             "form": "pounding",
#             "tags": [
#                 "participle",
#                 "present"
#             ]
#         },
#         {
#             "form": "pounded",
#             "tags": [
#                 "participle",
#                 "past"
#             ]
#         },
#         {
#             "form": "pounded",
#             "tags": [
#                 "past"
#             ]
#         },
#         {
#             "form": "poun",
# ...

# %% [markdown]
# Define example data of a translation block from the data above.
# Pretty-Print this for a better overview as well.

# %%
data = {"word": "pound", "translations": [{"lang": "Bulgarian", "word": "удрям"}, {"lang": "Bulgarian", "word": "блъскам"}, {"lang": "Czech", "word": "bušit"}, {"lang": "Dutch", "word": "beuken"}, {"lang": "Ewe", "word": "to"}, {"lang": "Finnish", "word": "takoa"}, {"lang": "Finnish", "word": "rusikoida"}, {"lang": "French", "word": "pilonner"}, {"lang": "Galician", "word": "mazar"}, {"lang": "Greek", "word": "σφυροκοπώ"}, {"lang": "Hungarian", "word": "dobogtat"}, {"lang": "Icelandic", "word": "banga"}, {"lang": "Irish", "word": "tuargain"}, {"lang": "Italian", "word": "battere"}, {"lang": "Italian", "word": "martellare"}, {"lang": "Italian", "word": "colpire"}, {"lang": "Italian", "word": "pestare"}, {"lang": "Italian", "word": "flagellare"}, {"lang": "Latin", "word": "pīnsō"}, {"lang": "Latin", "word": "cūdō"}, {"lang": "Latin", "word": "tundō"}, {"lang": "Lithuanian", "word": "daužyti"}, {"lang": "Maori", "word": "pātukituki"}, {"lang": "Maori", "word": "tuki"}, {"lang": "Middle English", "word": "pounen"}, {"lang": "Old Norse", "word": "banga"}, {"lang": "Ottoman Turkish", "word": "چالمق"}, {"lang": "Polish", "word": "walić"}, {"lang": "Polish", "word": "walnąć"}, {"lang": "Polish", "word": "bachnąć"}, {"lang": "Portuguese", "word": "bater"}, {"lang": "Quechua", "word": "takay"}, {"lang": "Romanian", "word": "pisa"}, {"lang": "Romanian", "word": "bate"}, {"lang": "Russian", "word": "колоти́ть"}, {"lang": "Scots", "word": "pran"}, {"lang": "Scottish Gaelic", "word": "buail"}, {"lang": "Slovak", "word": "biť"}, {"lang": "Slovak", "word": "tĺcť"}, {"lang": "Spanish", "word": "pilar"}, {"lang": "Swedish", "word": "banka"}, {"lang": "Telugu", "word": "దంచు"}, {"lang": "Tetum", "word": "fai"}, {"lang": "Tetum", "word": "tuku"}, {"lang": "Thai", "word": "ทุบ"}, {"lang": "Thai", "word": "ตี"}, {"lang": "ǃXóõ", "word": "!qhāã"}, {"lang": "Aromanian", "word": "chisedz"}, {"lang": "Assamese", "word": "খুন্দ"}, {"lang": "Belarusian", "word": "таўчы́"}, {"lang": "Bulgarian", "word": "стривам"}, {"lang": "Bulgarian", "word": "счуквам"}, {"lang": "Cherokee", "word": "ᎠᏍᏙᎠ"}, {"lang": "Esperanto", "word": "pisti"}, {"lang": "Ewe", "word": "to"}, {"lang": "Finnish", "word": "murskata"}, {"lang": "Galician", "word": "triturar"}, {"lang": "Galician", "word": "pulverizar"}, {"lang": "German", "word": "zerstampfen"}, {"lang": "Greek", "word": "διαλύω"}, {"lang": "Higaonon", "word": "asud"}, {"lang": "Icelandic", "word": "banga"}, {"lang": "Italian", "word": "frantumare"}, {"lang": "Italian", "word": "tritare"}, {"lang": "Italian", "word": "triturare"}, {"lang": "Italian", "word": "polverizzare"}, {"lang": "Korean", "word": "(방아)찧다"}, {"lang": "Korean", "word": "빻다"}, {"lang": "Middle English", "word": "pounen"}, {"lang": "Middle English", "word": "brayen"}, {"lang": "Old Norse", "word": "banga"}, {"lang": "Portuguese", "word": "triturar"}, {"lang": "Portuguese", "word": "pulverizar"}, {"lang": "Romanian", "word": "pisa"}, {"lang": "Russian", "word": "толо́чь"}, {"lang": "Russian", "word": "раздробля́ть"}, {"lang": "Russian", "word": "дроби́ть"}, {"lang": "Russian", "word": "моло́ть"}, {"lang": "Russian", "word": "кроши́ть"}, {"lang": "Scots", "word": "champ"}, {"lang": "Scots", "word": "pran"}, {"lang": "Slovak", "word": "drviť"}, {"lang": "Slovak", "word": "rozdrviť"}, {"lang": "Spanish", "word": "pulverizar"}, {"lang": "Telugu", "word": "దంచు"}, {"lang": "Thai", "word": "ตำ"}, {"lang": "Thai", "word": "บด"}, {"lang": "Turkish", "word": "parçalara ayırmak"}, {"lang": "Ukrainian", "word": "товкти́"}, {"lang": "Bulgarian", "word": "тъпча се"}, {"lang": "Finnish", "word": "imaista"}, {"lang": "Italian", "word": "ingurgitare"}, {"lang": "Italian", "word": "trangugiare"}, {"lang": "Italian", "word": "affogarsi"}, {"lang": "Portuguese", "word": "devorar"}, {"lang": "Russian", "word": "ло́пать"}, {"lang": "Finnish", "word": "pommittaa"}, {"lang": "Finnish", "word": "hakata"}, {"lang": "Finnish", "word": "jyskyttää"}, {"lang": "German", "word": "klopfen"}, {"lang": "Hungarian", "word": "dobogtat"}, {"lang": "Italian", "word": "battere"}, {"lang": "Italian", "word": "picchiare"}, {"lang": "Polish", "word": "walić"}, {"lang": "Slovak", "word": "biť"}, {"lang": "Slovak", "word": "búšiť"}, {"lang": "Slovak", "word": "pulzovať"}, {"lang": "Swedish", "word": "slå"}, {"lang": "Swedish", "word": "bulta"}, {"lang": "Bulgarian", "word": "чукам"}, {"lang": "Finnish", "word": "ryskyttää"}, {"lang": "French", "word": "pilonner"}, {"lang": "Polish", "word": "walić"}, {"lang": "Portuguese", "word": "socar"}, {"lang": "Finnish", "word": "marssia"}, {"lang": "Finnish", "word": "jyskyttää"}, {"lang": "Haryanvi", "word": "खुड़का"}], "raw_glosses": ["(transitive) To strike hard, usually repeatedly.", "(transitive) To crush to pieces; to pulverize.", "(transitive, slang) To eat or drink very quickly.", "(transitive, baseball, slang) To pitch consistently to a certain location.", "(intransitive, of a body part, generally heart, blood, or head) To beat strongly or throb.", "(transitive, vulgar, slang) To penetrate sexually, with vigour.", "(engineering) To make a jarring noise, as when running."]}
pprint(data)
# Out:
# {
#     "word": "pound",
#     "translations": [
#         {
#             "lang": "Bulgarian",
#             "word": "удрям"
#         },
#         {
#             "lang": "Bulgarian",
#             "word": "блъскам"
#         },
#         {
#             "lang": "Czech",
#             "word": "bušit"
#         },
#         {
#             "lang": "Dutch",
#             "word": "beuken"
#         },
#         {
#             "lang": "Ewe",
#             "word": "to"
#         },
#         {
#             "lang": "Finnish",
#             "word": "takoa"
#         },
#         {
#             "lang": "Finnish",
#             "word": "rusikoida"
#         },
#         {
#             "lang": "French",
#             "word": "pilonner"
#         },
#         {
#             "lang": "Galician",
#             "word": "mazar"
#         },
#         {
#             "lang": "Greek",
#             "word": "σφυροκοπώ"
#         },
#         {
#             "lang": "Hungarian",
# ...

# %% [markdown]
# Another example of a translation block.

# %%
data = {"word": "pound", "translations": [{"lang": "Bulgarian", "word": "удрям"}, {"lang": "Bulgarian", "word": "блъскам"}, {"lang": "Czech", "word": "bušit"}, {"lang": "Dutch", "word": "beuken"}, {"lang": "Ewe", "word": "to"}, {"lang": "Finnish", "word": "takoa"}, {"lang": "Finnish", "word": "rusikoida"}, {"lang": "French", "word": "pilonner"}, {"lang": "Galician", "word": "mazar"}, {"lang": "Greek", "word": "σφυροκοπώ"}, {"lang": "Hungarian", "word": "dobogtat"}, {"lang": "Icelandic", "word": "banga"}, {"lang": "Irish", "word": "tuargain"}, {"lang": "Italian", "word": "battere"}, {"lang": "Italian", "word": "martellare"}, {"lang": "Italian", "word": "colpire"}, {"lang": "Italian", "word": "pestare"}, {"lang": "Italian", "word": "flagellare"}, {"lang": "Latin", "word": "pīnsō"}, {"lang": "Latin", "word": "cūdō"}, {"lang": "Latin", "word": "tundō"}, {"lang": "Lithuanian", "word": "daužyti"}, {"lang": "Maori", "word": "pātukituki"}, {"lang": "Maori", "word": "tuki"}, {"lang": "Middle English", "word": "pounen"}, {"lang": "Old Norse", "word": "banga"}, {"lang": "Ottoman Turkish", "word": "چالمق"}, {"lang": "Polish", "word": "walić"}, {"lang": "Polish", "word": "walnąć"}, {"lang": "Polish", "word": "bachnąć"}, {"lang": "Portuguese", "word": "bater"}, {"lang": "Quechua", "word": "takay"}, {"lang": "Romanian", "word": "pisa"}, {"lang": "Romanian", "word": "bate"}, {"lang": "Russian", "word": "колоти́ть"}, {"lang": "Scots", "word": "pran"}, {"lang": "Scottish Gaelic", "word": "buail"}, {"lang": "Slovak", "word": "biť"}, {"lang": "Slovak", "word": "tĺcť"}, {"lang": "Spanish", "word": "pilar"}, {"lang": "Swedish", "word": "banka"}, {"lang": "Telugu", "word": "దంచు"}, {"lang": "Tetum", "word": "fai"}, {"lang": "Tetum", "word": "tuku"}, {"lang": "Thai", "word": "ทุบ"}, {"lang": "Thai", "word": "ตี"}, {"lang": "ǃXóõ", "word": "!qhāã"}], "raw_glosses": ["(transitive) To strike hard, usually repeatedly."]}
pprint(data)
# Out:
# {
#     "word": "pound",
#     "translations": [
#         {
#             "lang": "Bulgarian",
#             "word": "удрям"
#         },
#         {
#             "lang": "Bulgarian",
#             "word": "блъскам"
#         },
#         {
#             "lang": "Czech",
#             "word": "bušit"
#         },
#         {
#             "lang": "Dutch",
#             "word": "beuken"
#         },
#         {
#             "lang": "Ewe",
#             "word": "to"
#         },
#         {
#             "lang": "Finnish",
#             "word": "takoa"
#         },
#         {
#             "lang": "Finnish",
#             "word": "rusikoida"
#         },
#         {
#             "lang": "French",
#             "word": "pilonner"
#         },
#         {
#             "lang": "Galician",
#             "word": "mazar"
#         },
#         {
#             "lang": "Greek",
#             "word": "σφυροκοπώ"
#         },
#         {
#             "lang": "Hungarian",
# ...

# %% [markdown]
# Yet another translation block example.

# %%
data = {"word": "pound", "translations": [{"lang": "Aromanian", "word": "chisedz"}, {"lang": "Assamese", "word": "খুন্দ"}, {"lang": "Belarusian", "word": "таўчы́"}, {"lang": "Bulgarian", "word": "стривам"}, {"lang": "Bulgarian", "word": "счуквам"}, {"lang": "Cherokee", "word": "ᎠᏍᏙᎠ"}, {"lang": "Esperanto", "word": "pisti"}, {"lang": "Ewe", "word": "to"}, {"lang": "Finnish", "word": "murskata"}, {"lang": "Galician", "word": "triturar"}, {"lang": "Galician", "word": "pulverizar"}, {"lang": "German", "word": "zerstampfen"}, {"lang": "Greek", "word": "διαλύω"}, {"lang": "Higaonon", "word": "asud"}, {"lang": "Icelandic", "word": "banga"}, {"lang": "Italian", "word": "frantumare"}, {"lang": "Italian", "word": "tritare"}, {"lang": "Italian", "word": "triturare"}, {"lang": "Italian", "word": "polverizzare"}, {"lang": "Korean", "word": "(방아)찧다"}, {"lang": "Korean", "word": "빻다"}, {"lang": "Middle English", "word": "pounen"}, {"lang": "Middle English", "word": "brayen"}, {"lang": "Old Norse", "word": "banga"}, {"lang": "Portuguese", "word": "triturar"}, {"lang": "Portuguese", "word": "pulverizar"}, {"lang": "Romanian", "word": "pisa"}, {"lang": "Russian", "word": "толо́чь"}, {"lang": "Russian", "word": "раздробля́ть"}, {"lang": "Russian", "word": "дроби́ть"}, {"lang": "Russian", "word": "моло́ть"}, {"lang": "Russian", "word": "кроши́ть"}, {"lang": "Scots", "word": "champ"}, {"lang": "Scots", "word": "pran"}, {"lang": "Slovak", "word": "drviť"}, {"lang": "Slovak", "word": "rozdrviť"}, {"lang": "Spanish", "word": "pulverizar"}, {"lang": "Telugu", "word": "దంచు"}, {"lang": "Thai", "word": "ตำ"}, {"lang": "Thai", "word": "บด"}, {"lang": "Turkish", "word": "parçalara ayırmak"}, {"lang": "Ukrainian", "word": "товкти́"}], "raw_glosses": ["(transitive) To crush to pieces; to pulverize."]}
pprint(data)
# Out:
# {
#     "word": "pound",
#     "translations": [
#         {
#             "lang": "Aromanian",
#             "word": "chisedz"
#         },
#         {
#             "lang": "Assamese",
#             "word": "খুন্দ"
#         },
#         {
#             "lang": "Belarusian",
#             "word": "таўчы́"
#         },
#         {
#             "lang": "Bulgarian",
#             "word": "стривам"
#         },
#         {
#             "lang": "Bulgarian",
#             "word": "счуквам"
#         },
#         {
#             "lang": "Cherokee",
#             "word": "ᎠᏍᏙᎠ"
#         },
#         {
#             "lang": "Esperanto",
#             "word": "pisti"
#         },
#         {
#             "lang": "Ewe",
#             "word": "to"
#         },
#         {
#             "lang": "Finnish",
#             "word": "murskata"
#         },
#         {
#             "lang": "Galician",
#             "word": "triturar"
#         },
#         {
#             "lang": "Galician",
# ...
